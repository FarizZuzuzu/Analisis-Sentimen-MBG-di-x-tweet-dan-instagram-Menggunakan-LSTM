# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DRIVE_PATH = '/content/drive/MyDrive/SKRIPSI_Yeni'

# Pastikan direktori ada
import os
os.makedirs(DRIVE_PATH, exist_ok=True)

# Definisikan path untuk data mentah setelah scraping
RAW_DATA_PATH = f'{DRIVE_PATH}/hasil_x1_comments.csv'

print(f"Direktori Google Drive: {DRIVE_PATH}")
print(f"Path Data Mentah: {RAW_DATA_PATH}")
# Out:
# Direktori Google Drive: /content/drive/MyDrive/SKRIPSI_Yeni
# Path Data Mentah: /content/drive/MyDrive/SKRIPSI_Yeni/hasil_x1_comments.csv

# %% [markdown]
# install library

# %%
# apify-client : untuk menjalankan Actor dan mengambil dataset dari Apif
# pandas : untuk mengolah data dan menyimpan CSV/Excel
# openpyxi : engine untuk membuat file Excel •xlsx
# tqam : membuat progress bar di loop
# rich : membuat tampilan output terminal lebih cantik (tabel, warna)

# !pip install apify-client pandas openpyxl tqdm rich

from apify_client import ApifyClient
from tqdm import tqdm
from rich.console import Console
from rich.table import Table
from rich import box
import pandas as pd
# Console rich digunakan untuk menampilkan teks berwarna & tabel
console = Console()
# Out:
# Requirement already satisfied: apify-client in /usr/local/lib/python3.12/dist-packages (3.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (13.9.4)
# Requirement already satisfied: colorama>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from apify-client) (0.4.6)
# Requirement already satisfied: impit~=0.13.0 in /usr/local/lib/python3.12/dist-packages (from apify-client) (0.13.1)
# Requirement already satisfied: more-itertools>=10.0.0 in /usr/local/lib/python3.12/dist-packages (from apify-client) (10.8.0)
# Requirement already satisfied: pydantic>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from pydantic[email]>=2.11.0->apify-client) (2.13.4)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.3)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.0->pydantic[email]>=2.11.0->apify-client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.0->pydantic[email]>=2.11.0->apify-client) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.0->pydantic[email]>=2.11.0->apify-client) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.0->pydantic[email]>=2.11.0->apify-client) (0.4.2)
# Requirement already satisfied: email-validator>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pydantic[email]>=2.11.0->apify-client) (2.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.0->apify-client) (2.8.0)
# Requirement already satisfied: idna>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.0->apify-client) (3.18)

# %% [markdown]
# inisialisasi client

# %%
# 1. Inisialisasi Apify Client
# ================================================================
# Menghubungkan script dengan akun Apify menggunakan API Token.
# Tanpa token, Actor tidak bisa dijalankan.
API_TOKEN = "masukkan API dari Apify ke sini" # + GANTI TOKEN APIFY KAMU

client = ApifyClient(API_TOKEN)

console.rule("[bold cyan]ê Inisialisasi Client Apify")
# Out:
# ─────────────────────────────────────────── ê Inisialisasi Client Apify ───────────────────────────────────────────

# %% [markdown]
# input actor

# %%
run_input = {
    "maxCommentsPerPost": 100,
    "postUrls": [
        "https://x.com/regar_op0sisi/status/2079208098141794557?s=20",
        "https://x.com/Beritasatu/status/2079148987916107847?s=20",
        "https://x.com/kompascom/status/2077241661911130210?s=20",
        "https://x.com/tempodotco/status/2079899270199595250?s=20",
#         'https://x.com/Naandaa27/status/2077672020863533184?s=20',
#         'https://x.com/txtdrimedia/status/2079154852257513702?s=20'
#     ]
# }

# %% [markdown]
# jalankan actor

# %%
 # ===================================================================================
# 3. Menjalankan Actor
# ===================================================================================

console.rule("[bold yellow]  Menjalankan Actor Instagram Comment Scraper")
console.print("Harap tunggu, proses scraping sedang berjalan...")

# Remove duplicate URLs from run_input['directUrls'] to prevent InvalidRequestError
run_input['postUrls'] = list(set(run_input['postUrls']))

run = client.actor("clappi/x-twitter-comments-scraper").call(run_input=run_input)

console.print("[bold green] Actor selesai dijalankan!")
# Out:
# ──────────────────────────────────   Menjalankan Actor Instagram Comment Scraper ──────────────────────────────────
# Harap tunggu, proses scraping sedang berjalan...
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> Status: RUNNING, Message:
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:58.353Z ACTOR: Pulling container image of build 6iaZg2jlaK8ofhOZT from registry.
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:58.355Z ACTOR: Creating container.
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:58.400Z ACTOR: Starting container.
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:58.400Z ACTOR: Running under "LIMITED_PERMISSIONS".
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:58.966Z
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:58.967Z > x-comment-scraper@1.0.0 start
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:58.967Z > node src/main.js
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:58.968Z
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.434Z INFO  System info {"apifyVersion":"3.7.1","apifyClientVersion":"2.23.1","crawleeVersion":"3.16.0","osType":"Linux","nodeVersion":"v20.20.2"}
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.561Z Starting to scrape comments from 25 post(s), up to 100 comments each...
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.670Z Using account: 8820497a-f53a-40cb-8ff8-9b652cb3cb7b, proxy: http://user-*********-country-us-zip-75201-session-ac9cf30c2bc44c448b3db6cf03511bfc-sessionduration-1439:***@gate.decodo.com:10001
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.671Z
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.671Z [1/25] https://x.com/menuembegejelek/status/2032285800097071555?s=20 (ID: 2032285800097071555)
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.675Z
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.677Z [2/25] https://x.com/ardisatriawan/status/2079031883900633488?s=20 (ID: 2079031883900633488)
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.677Z
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.678Z [3/25] https://x.com/kompascom/status/2079198548089041058?s=20 (ID: 2079198548089041058)
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.678Z
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.679Z [4/25] https://x.com/LambeSahamjja/status/2079728084748738660?s=20 (ID: 2079728084748738660)
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.680Z
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.680Z [5/25] https://x.com/kompascom/status/2079052174693441955?s=20 (ID: 2079052174693441955)
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.682Z
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.682Z [6/25] https://x.com/Hidupsebagai62/status/2064707522078879832?s=20 (ID: 2064707522078879832)
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.683Z
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.683Z [7/25] https://x.com/txtdrimedia/status/2079189585167532416?s=20 (ID: 2079189585167532416)
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.684Z
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.684Z [8/25] https://x.com/regar_op0sisi/status/2079208098141794557?s=20 (ID: 2079208098141794557)
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.685Z
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.686Z [9/25] https://x.com/ARSIPAJA/status/1893601702273806465?s=20 (ID: 1893601702273806465)
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.686Z
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:08:59.687Z [10/25] https://x.com/regar_op0sisi/status/2079741597135372765?s=20 (ID: 2079741597135372765)
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:09:13.070Z [7/25] Done — 100 comments
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:09:13.073Z [11/25] Done — 100 comments
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:09:13.163Z [22/25] Done — 100 comments
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:09:13.165Z
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> 2026-07-27T19:09:13.165Z Done. 2459 total comments scraped.
# [apify.x-twitter-comments-scraper runId:ma7k4T0OEaujPDC0l] -> Status: SUCCEEDED, Message:
#  Actor selesai dijalankan!

# %% [markdown]
# ambil hasil Scraping

# %%
# =======================================================================
# 4. Mengambil hasil scraping dengan progress bar
#========================================================================

# Setelah Actor selesai, hasilnya disimpan ke Dataset Apify.
# Kita ambil dataset tersebut dan masukkan ke dalam list 'results'.
console.rule("[bold cyan] Mengambil Data dari Dataset")

results = []

# 'run' is already the Run Pydantic model, so its details are directly accessible
# No need to call .get_sync() as 'run' itself holds the details.

dataset_id = run.default_dataset_id

# Auto-detect jumlah item Jika tersedia, Jika tidak pakai estimasi
# → progress bar akan menampilkan estimasi jumlah item
# Access 'item_count' directly from the 'run' object
estimated_total = run.item_count if hasattr(run, 'item_count') and run.item_count is not None else 3000

# Gunakan tqdm untuk menampilkan progress bar saat data diambil
for item in tqdm(client.dataset(dataset_id).iterate_items(),
                 desc="Mengambil data",
                 unit="item",
                 total=estimated_total):
    results.append(item)
# Out:
# ──────────────────────────────────────────  Mengambil Data dari Dataset ───────────────────────────────────────────
# Mengambil data:  70%|██████▉   | 2087/3000 [00:00<00:00, 3138.54item/s]

# %%
# ===================================================================================
# 5. Menyimpan ke CSV & Excel
# ===================================================================================

# Penyimpanan data dilakukan setelah scraping selesai.
# File akan disimpan dalam dua format: CSV dan Excel (.xlsx)
console.rule("[bold green]* Menyimpan Data ke File")

# Simpan ke RAW_DATA_PATH di Google Drive
csv_file = RAW_DATA_PATH
excel_file = f"{DRIVE_PATH}/hasil_x_comments.xlsx"

if results:
  df = pd.DataFrame(results)   # mengubah list hasil scraping jadi dataframe

  # Simpan CSV
  df.to_csv(csv_file, index=False, encoding='utf-8-sig')

  # Simpan Excel menggunakan openpyxl sebagai engine
  df.to_excel(excel_file, index=False, engine="openpyxl")

  # Membuat tabel ringkasan menggunakan rich
  table = Table(title="Ringkasan Output", box=box.HEAVY)
  table.add_column("Jenis File", style="cyan" , justify="center")
  table.add_column ("Nama File", style="green")
  table.add_column ("Jumlah Baris", style="yellow", justify="center")

  table.add_row("CSV", csv_file, str(len(df)))
  table.add_row("Excel", excel_file, str(len(df)))

  console.print (table)

else:
  console.print("[bold red] Tidak ada data ditemukan!")
# Out:
# ──────────────────────────────────────────── * Menyimpan Data ke File ─────────────────────────────────────────────
#                                     Ringkasan Output
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┓
# ┃ Jenis File ┃ Nama File                                                 ┃ Jumlah Baris ┃
# ┣━━━━━━━━━━━━╋━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╋━━━━━━━━━━━━━━┫
# ┃    CSV     ┃ /content/drive/MyDrive/SKRIPSI_Yeni/hasil_x1_comments.csv ┃     2087     ┃
# ┃   Excel    ┃ /content/drive/MyDrive/SKRIPSI_Yeni/hasil_x_comments.xlsx ┃     2087     ┃
# ┗━━━━━━━━━━━━┻━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━━━┛

# %%
# ================================================================================
# 6. Baca kembali CSV untuk verifikasi
# ================================================================================

from IPython.display import display # Untuk menampilkan DataFrame rapi

print("\n Menverifikasi isi dataset...")

data = pd.read_csv(RAW_DATA_PATH) # Membaca dari RAW_DATA_PATH

print("\n=== Informasi Struktur Data ===")
display(data.info()) # Lebih rapi

print("\n=== Contoh 5 Baris Pertama ===")
display(data.head (5))  # Tampil sebagai tabel
# Out:
#  Menverifikasi isi dataset...
#
# === Informasi Struktur Data ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2087 entries, 0 to 2086
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   post_url          2087 non-null   object
#  1   post_id           2087 non-null   int64
#  2   comment_id        2087 non-null   int64
#  3   text              2087 non-null   object
#  4   reply_to          2087 non-null   object
#  5   created_at        2087 non-null   object
#  6   likes             2087 non-null   int64
#  7   retweets          2087 non-null   int64
#  8   replies           2087 non-null   int64
#  9   quotes            2087 non-null   int64
#  10  views             2085 non-null   float64
#  11  author_id         2087 non-null   int64
#  12  author_username   2087 non-null   object
#  13  author_name       2087 non-null   object
#  14  author_followers  2087 non-null   int64
#  15  author_verified   2087 non-null   bool
# dtypes: bool(1), float64(1), int64(8), object(6)
# memory usage: 246.7+ KB
# None
# === Contoh 5 Baris Pertama ===
#                                             post_url              post_id  \
# 0  https://x.com/kompascom/status/207905217469344...  2079052174693441955
# 1  https://x.com/kompascom/status/207905217469344...  2079052174693441955
# 2  https://x.com/kompascom/status/207905217469344...  2079052174693441955
# 3  https://x.com/kompascom/status/207905217469344...  2079052174693441955
# 4  https://x.com/kompascom/status/207905217469344...  2079052174693441955
#
#             comment_id                                               text  \
# 0  2079140802094322080  Kaya raya banget nih cokelat dan kacang ijo. \...
# 1  2079128687145033875  Sayangnya dia berbicara di hadapan makhluk "bu...
# 2  2079176794666868920                            https://t.co/cyBe8Viy3V
# 3  2079316160856949070  Rakyat : saking bebalnya. Begitu banyak proble...
# 4  2079208541777514848  Orang2 seragam ini kayak gak punya kerjaan lai...
#
#         reply_to                      created_at  likes  retweets  replies  \
# 0  ['kompascom']  Mon Jul 20 09:46:10 +0000 2026     51         3        1
# 1  ['kompascom']  Mon Jul 20 08:58:02 +0000 2026     23         0        0
# 2  ['kompascom']  Mon Jul 20 12:09:11 +0000 2026     20         1        0
# 3  ['kompascom']  Mon Jul 20 21:22:59 +0000 2026     15         1        0
# 4  ['kompascom']  Mon Jul 20 14:15:20 +0000 2026     11         3        0
#
#    quotes   views            author_id author_username  \
# 0       0  1719.0           2591775756    NgajarDiDesa
# 1       0   799.0  1589167272517832704  sayyid_sukardi
# 2       0  1243.0  1963222091039391744    volterposisi
# 3       0   726.0            154002393        liriksoe
# 4       0  1141.0   922447876449452034      oilyjojoba
#
#                 author_name  author_followers  author_verified
# 0                BuGuruDesa              3249             True
# 1  ĸιcĸ тнe corrυpтor'ѕ aѕѕ                13            False
# 2            volter oposisi               176            False
# 3                       Soe              1028            False
# 4               SUPER maemi                24            False
